# %% [markdown]
# # Package Import

# %%
import seaborn as sns
import os
import pickle
import matplotlib.pyplot as plt
import random
from analysis import *

# %% [markdown]
# # Compile Subject Data

# %%
# sub_data is a list of dicts, one per subj
sub_data = mass_data('../../data')

# %%
for s in sub_data:

    k = s['images']
    cued_split = [words for segments in s['cued'] for words in segments.split('_')]
    cued_split = [word+'.jpg' for word in cued_split if word[-3:]!='jpg'] + [word for word in cued_split if word[-3:]=='jpg']
    #print(cued_split)

    uncued_split = [words for segments in s['uncued'] for words in segments.split('_')]
    uncued_split = [word+'.jpg' for word in uncued_split if word[-3:]!='jpg'] + [word for word in uncued_split if word[-3:]=='jpg']
    #print(len(uncued_split))

    u1 = set(s['images']).intersection(set(cued_split))
    u2 = set(s['images']).intersection(set(uncued_split))

    conglom = cued_split+uncued_split
    #print(conglom)

    u3 = [x for x in k if x not in conglom]
    u4 = [x for x in k if x in conglom]


    
    #print(len(u1))
    print('prev seen:')
    print(len(u1)+len(u2))
    print('rand:')
    print(len(u3))
    
    #print(float((len(u1))/len(k))+(len(u2)/len(k)))
    
    #print(float(len(u3))/len(k))
    #print(float(len(u4))/len(k))
    #print(' ')
    
    
    #print(len(u3))
    #print(len(u4))
    print(' ')
len(s['images'])/8
# Out:
# prev seen:
# 0
# rand:
# 0
#
# prev seen:
# 0
# rand:
# 0
#
# prev seen:
# 64
# rand:
# 256
#
# prev seen:
# 20
# rand:
# 20
#
# prev seen:
# 160
# rand:
# 160
# 40.0

# %%
for s in sub_data:
    for x in [s['cued'],s['uncued'], s['images']]:
        if len(x) == len(set(x)):
            print('True')
        else:
            print('cure repeat, internal')

    for s in sub_data:
        if len([x for x in s['cued'] if x in s['uncued']]):
            print('Cue repeat, external')
    
len(s['cued'])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# 80

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
import seaborn.apionly as sns
import matplotlib.gridspec as gridspec
import pandas as pd
# %matplotlib inline  


for x,subject in enumerate(sub_data):
    nothing = 0  
    #print("SUBJECT " + str(x) + ' Overview')

    # can try to use the line below to ouput subplots for each subject
    #fig, [ax1, ax2, ax3] = plt.subplots(1,3, figsize=(20,5))#, gridspec_kw=gridkw)
    
    #sns.barplot(data=plot_rl(subject))#, ax=ax1)
    sns.boxplot(data=plot_rl(subject))
    plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
print(cue_tuples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c75d993d62e7> in <module>()
# ----> 1 print(cue_tuples)
#
# NameError: name 'cue_tuples' is not defined

# %%
len(rand_count)

# %%
plot_rl(subject)
# Out:
#                       images ratings                                   cued  \
# 0    sunabtrnbvpppgczjim.jpg    None  00772941201fa_sunafpfpiiujzoesnqg.jpg
# 1          00700941121fa.jpg    None  00796941205fa_sunaguchqqnrtodtezq.jpg
# 2    sunabcuurugvxwparpk.jpg    None  00681941121fa_sunadqmjrhfjyuzyvdd.jpg
# 3    sunabasphceswhwwqvv.jpg    None  00270940422fb_sunabllobxadqcyttej.jpg
# 4          00630941031fa.jpg    None  00705960530fa_sunaduslxfzlbxlllnz.jpg
# 5    sunacacflqoyxhsqzhe.jpg    None  00915960620fa_sunapileznnbbmrwoei.jpg
# 6    sunapileznnbbmrwoei.jpg    None  00147931230fb_sunaatpkocdkocwxpkb.jpg
# 7    sunacbeefkxpymwevpk.jpg    None  00754941201fa_sunaffgsyyvoqdlkmnk.jpg
# 8          00761960627fa.jpg    None  00700941121fa_sunadsgmtznewzyasnk.jpg
# 9    sunagoufulkpsxrmklt.jpg    None  00913960530fa_sunaooffzffbhcpirmm.jpg
# 10   sunaooffzffbhcpirmm.jpg    None  00505960627fa_sunabzuqsrgcsonqlkz.jpg
# ...

# %%
import numpy as np

# %%
sns.barplot(pd.DataFrame([cued_count, uncued_count, rand_count]).T)

# %%
df = pd.DataFrame([cued_count, uncued_count, rand_count]).T
df.columns = ['cued', 'uncued','rand_count']

# %%
plt.bar([cued, uncued, rand_count])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-482-7278c094bf5e> in <module>()
# ----> 1 plt.bar([cued, uncued, rand_count])
#
# NameError: name 'cued' is not defined

# %%
# Out:
#                        ratings   cued_RT  \
# 0    [(None, 0.0), (2, 1.252)]  0.530294
# 1     [(None, 0.0), (1, 1.31)]  0.397502
# 2    [(None, 0.0), (1, 1.598)]  0.461454
# 3                [(None, 0.0)]  0.499760
# 4    [(None, 0.0), (2, 1.061)]  0.534415
# 5    [(None, 0.0), (1, 0.646)]  0.510779
# 6    [(None, 0.0), (3, 0.994)]  0.560205
# 7    [(None, 0.0), (1, 1.086)]  0.412159
# 8    [(None, 0.0), (1, 0.978)]  0.427253
# 9    [(None, 0.0), (3, 1.126)]  0.411743
# 10   [(None, 0.0), (4, 0.932)]  0.566683
# 11   [(None, 0.0), (2, 1.528)]  0.657462
# 12   [(None, 0.0), (1, 1.316)]  0.454545
# 13   [(None, 0.0), (4, 1.096)]  0.539163
# 14   [(None, 0.0), (2, 1.178)]  0.376224
# 15   [(None, 0.0), (1, 1.013)]  0.396542
# 16   [(None, 0.0), (4, 1.044)]  0.384310
# 17   [(None, 0.0), (1, 1.128)]  0.517602
# 18   [(None, 0.0), (3, 1.096)]  0.478230
# 19   [(None, 0.0), (4, 0.744)]  0.414292
# 20   [(None, 0.0), (4, 0.911)]  0.652553
# 21   [(None, 0.0), (2, 1.646)]  0.465949
# ...
