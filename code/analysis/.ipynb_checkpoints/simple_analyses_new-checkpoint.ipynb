# %%
import seaborn as sns
import os
import pickle
import matplotlib.pyplot as plt
import random
import matplotlib.pyplot as plt #repeat?
import seaborn as sns #repeat?
import matplotlib.gridspec as gridspec
import pandas as pd 
from scipy.stats import ttest_rel
import numpy as np
from sklearn import metrics
from analysis import *
# %matplotlib inline 
import math

# %%
# load data
sub_data = halfsies(mass_data('../../data'))
pres = mass_df(halfsies(sub_data), typ='pres')
rec = mass_df(halfsies(sub_data), typ='rec')

# %%
len(sub_data)
# Out:
# 3

# %%
#pres = mass_df(mass_data('../../data'), typ='pres')
#rec = mass_df(mass_data('../../data'), typ='rec')

# %%
pres.head()
# Out:
#       cue_tuples                                  cued  \
# 0  (cue_R, L, 0)  26437107.thl_sunaydywdmvlfddbxbk.jpg
# 1  (cue_R, L, 1)  26426575.thl_sunajwqkfsykceonyig.jpg
# 2  (cue_R, L, 0)  26378596.thl_sunaenwuebvlpdmntju.jpg
# 3  (cue_R, L, 0)  26373407.thl_sunacycdoztxoluxjyk.jpg
# 4  (cue_R, L, 0)  26427867.thl_sunakodkcslgqhqlgwl.jpg
#
#                                  uncued  subject  is_cued_RT
# 0  22827276.thl_sunaaiqiqcggrskoqgy.jpg        0           1
# 1  26424075.thl_sunaipyohrqlwngaqif.jpg        0           2
# 2  23014927.thl_sunabkmdplkdbvxriff.jpg        0           1
# 3  26379054.thl_sunaeouogqolxvggaoq.jpg        0           1
# 4  22923068.thl_sunabcfpwlpolnutyju.jpg        0           1

# %%
rec.head()
# Out:
#    familiarity            images cued_cat    location cat    category  \
# 0          1.0  26377133.thl.jpg        L    attended   F  unattended
# 1          3.0  26427867.thl.jpg        L    attended   F  unattended
# 2          2.0  22923440.thl.jpg    novel       novel   F       novel
# 3          NaN  26465824.thl.jpg    novel       novel   F       novel
# 4          1.0  26424075.thl.jpg        L  unattended   F  unattended
#
#   attention level report familiar  subject
# 0            side              no        0
# 1            side             yes        0
# 2           novel              no        0
# 3           novel             yes        0
# 4            none              no        0

# %%
# add subject numbers
subs1 = [[x]*80 for x in range(len(sub_data))]
flat_subs1 = [val for sublist in subs1 for val in sublist]
pres['subject'] = pd.Series(flat_subs1)

subs2 = [[x, x, x, x]*80 for x in range(len(sub_data))]
flat_subs2 = [val for sublist in subs2 for val in sublist]
rec['subject'] = pd.Series(flat_subs2) #CHECK TO SEE IF SUBJECT NUMBERS ARE CORRECTLY MATCHED WITH IMAGES!!!

# organize RT's
pres['is_cued_RT'] = pres.apply(lambda row: pr(row),axis=1)  
#pres['is_cued_RT'] = pres.apply(lambda row: pr(row),axis=1)  
pres = arrange_RTs(pres,sub_data)
pres['is_valid'] = pres.apply(lambda row: is_valid(row),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-035bb1de545d> in <module>()
#      11 pres['is_cued_RT'] = pres.apply(lambda row: pr(row),axis=1)
#      12 #pres['is_cued_RT'] = pres.apply(lambda row: pr(row),axis=1)
# ---> 13 pres = arrange_RTs(pres,sub_data)
#      14 pres['is_valid'] = pres.apply(lambda row: is_valid(row),axis=1)
#
# ~/Documents/github/attention-memory-task/code/analysis/analysis.py in arrange_RTs(pres, sub_data)
#     215
#     216
# --> 217     ser1 = pd.Series(cued_RT, index=df_pres1.index)
#     218     ser2 = pd.Series(uncued_RT, index=df_pres2.index)
#     219     df_pres1['RT'] = ser1
#
# /usr/local/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     226                                        raise_cast_failure=True)
#     227
# --> 228                 data = SingleBlockManager(data, index, fastpath=True)
#     229
#     230         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    3750         if not isinstance(block, Block):
#    3751             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 3752                                fastpath=True)
#    3753
#    3754         self.blocks = [block]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2459                      placement=placement, dtype=dtype)
#    2460
# -> 2461     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2462
#    2463 # TODO: flexible with index=None and/or items=None
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#      82             raise ValueError('Wrong number of items passed %d, placement '
#      83                              'implies %d' % (len(self.values),
# ---> 84                                              len(self.mgr_locs)))
#      85
#      86     @property
#
# ValueError: Wrong number of items passed 216, placement implies 106

# %%
pres[pres['subject']==1]
# Out:
# Empty DataFrame
# Columns: [cue_tuples, cued, uncued, subject, is_cued_RT, RT, is_valid]
# Index: []

# %%
rec.groupby(['cat', 'attention level','subject']).count()
# Out:
#                              familiarity  images  cued_cat  location  \
# cat attention level subject
# F   both            0                 20      20        20        20
#     category        0                 20      20        20        20
#     none            0                 20      20        20        20
#     novel           0                 80      80        80        80
#     side            0                 20      20        20        20
# L   both            0                 20      20        20        20
#     category        0                 20      20        20        20
#     none            0                 20      20        20        20
#     novel           0                 80      80        80        80
#     side            0                 20      20        20        20
#
#                              category  report familiar
# cat attention level subject
# F   both            0              20               20
#     category        0              20               20
#     none            0              20               20
#     novel           0              80               80
#     side            0              20               20
# L   both            0              20               20
#     category        0              20               20
#     none            0              20               20
#     novel           0              80               80
#     side            0              20               20

# %%
rec
# Out:
#     familiarity                   images cued_cat    location cat    category  \
# 0          None  sunabppokiyglaxpcha.jpg        L  unattended   L    attended
# 1          None  sunajjxttslobudoqbv.jpg        L  unattended   L    attended
# 2          None         26379430.thl.jpg    novel       novel   F       novel
# 3          None         22903148.thl.jpg        L    attended   F  unattended
# 4          None         26425370.thl.jpg        L  unattended   F  unattended
# 5          None  sunbloeoiozwjjsiamp.jpg    novel       novel   L       novel
# 6          None         22907432.thl.jpg    novel       novel   F       novel
# 7          None         26451318.thl.jpg    novel       novel   F       novel
# 8          None         26374146.thl.jpg        L  unattended   F  unattended
# 9          None         26429137.thl.jpg        L  unattended   F  unattended
# 10         None  sunaaylzyqlqrsmfwif.jpg        L    attended   L    attended
# 11         None         26379054.thl.jpg        L  unattended   F  unattended
# 12         None  sunafvcflzhlqloapyo.jpg    novel       novel   L       novel
# 13         None         26421740.thl.jpg        L    attended   F  unattended
# 14         None         23057742.thl.jpg        L    attended   F  unattended
# 15         None  sunafvwfsmqkjrutjta.jpg    novel       novel   L       novel
# 16         None  sunbwdrdvsweerwsdrj.jpg    novel       novel   L       novel
# 17         None  sunabtrnbvpppgczjim.jpg    novel       novel   L       novel
# 18         None         26422216.thl.jpg        L  unattended   F  unattended
# 19         None  sunaeouogqolxvggaoq.jpg        L  unattended   L    attended
# 20         None         22852032.thl.jpg    novel       novel   F       novel
# 21         None  sunagrmyoovzukhxmlo.jpg    novel       novel   L       novel
# 22         None  sunaofikylqtxphvdem.jpg        L  unattended   L    attended
# 23         None  sunadcphrizvfpljiqt.jpg        L  unattended   L    attended
# 24         None         26440756.thl.jpg    novel       novel   F       novel
# 25         None         22826832.thl.jpg    novel       novel   F       novel
# 26         None  sunbwaafjdebjzttuvq.jpg        L    attended   L    attended
# 27         None         10053213.thm.jpg    novel       novel   F       novel
# 28         None         22827408.thl.jpg    novel       novel   F       novel
# 29         None  sunaawsdjisukbbginm.jpg        L    attended   L    attended
# ..          ...                      ...      ...         ...  ..         ...
# 290        None         26432760.thl.jpg    novel       novel   F       novel
# 291        None         22896812.thl.jpg    novel       novel   F       novel
# 292        None  sunaavtbadenwnzeutj.jpg        L  unattended   L    attended
# 293        None  sunasrjlmglmjzbmqxb.jpg    novel       novel   L       novel
# 294        None  sunaibnpvhkdpdnzcnz.jpg        L  unattended   L    attended
# 295        None         10049816.thl.jpg    novel       novel   F       novel
# 296        None  sunahqrxievfeusiqlt.jpg    novel       novel   L       novel
# 297        None  sunathzzbcwjykldrem.jpg        L    attended   L    attended
# 298        None  sunajrujcsdxmfbssmc.jpg    novel       novel   L       novel
# 299        None  sunacvzhvcksnwqcqbw.jpg    novel       novel   L       novel
# 300        None         26373844.thl.jpg    novel       novel   F       novel
# 301        None  sunaahwnmtqsrhocysw.jpg        L  unattended   L    attended
# 302        None         22826748.thl.jpg        L  unattended   F  unattended
# 303        None         26424973.thl.jpg        L    attended   F  unattended
# 304        None         22887480.thl.jpg        L  unattended   F  unattended
# 305        None  sunaddsaeicthrfbkhe.jpg    novel       novel   L       novel
# 306        None         26427867.thl.jpg    novel       novel   F       novel
# 307        None         23070748.thl.jpg        L    attended   F  unattended
# 308        None  sunaloffvbvysigxent.jpg        L  unattended   L    attended
# 309        None  sunafvtpfczkzopbgue.jpg        L    attended   L    attended
# 310        None  sunbaejotfklekvpxcz.jpg        L    attended   L    attended
# 311        None  sunajawzbrlrwafowen.jpg        L    attended   L    attended
# 312        None  sunaajqmsaavkmgbsth.jpg        L    attended   L    attended
# 313        None  sunacsaovnjezqwbykf.jpg    novel       novel   L       novel
# 314        None         26428041.thl.jpg        L  unattended   F  unattended
# 315        None  sunagtumacdlmciqamz.jpg    novel       novel   L       novel
# 316        None  sunarceibpcyacbmfga.jpg    novel       novel   L       novel
# 317        None  sunagwswhkvnsmuszlz.jpg    novel       novel   L       novel
# 318        None         23060574.thl.jpg        L  unattended   F  unattended
# 319        None  sunaivflshbyfrfzhqb.jpg    novel       novel   L       novel
#
#     attention level report familiar  subject
# 0          category             yes        0
# 1          category             yes        0
# 2             novel             yes        0
# 3              side             yes        0
# 4              none             yes        0
# 5             novel             yes        0
# 6             novel             yes        0
# 7             novel             yes        0
# 8              none             yes        0
# 9              none             yes        0
# 10             both             yes        0
# 11             none             yes        0
# 12            novel             yes        0
# 13             side             yes        0
# 14             side             yes        0
# 15            novel             yes        0
# 16            novel             yes        0
# 17            novel             yes        0
# 18             none             yes        0
# 19         category             yes        0
# 20            novel             yes        0
# 21            novel             yes        0
# 22         category             yes        0
# 23         category             yes        0
# 24            novel             yes        0
# 25            novel             yes        0
# 26             both             yes        0
# 27            novel             yes        0
# 28            novel             yes        0
# 29             both             yes        0
# ..              ...             ...      ...
# 290           novel             yes        0
# 291           novel             yes        0
# 292        category             yes        0
# 293           novel             yes        0
# 294        category             yes        0
# 295           novel             yes        0
# 296           novel             yes        0
# 297            both             yes        0
# 298           novel             yes        0
# 299           novel             yes        0
# 300           novel             yes        0
# 301        category             yes        0
# 302            none             yes        0
# 303            side             yes        0
# 304            none             yes        0
# 305           novel             yes        0
# 306           novel             yes        0
# 307            side             yes        0
# 308        category             yes        0
# 309            both             yes        0
# 310            both             yes        0
# 311            both             yes        0
# 312            both             yes        0
# 313           novel             yes        0
# 314            none             yes        0
# 315           novel             yes        0
# 316           novel             yes        0
# 317           novel             yes        0
# 318            none             yes        0
# 319           novel             yes        0
#
# [320 rows x 9 columns]

# %%
g = sns.factorplot(col='subject', x='attention level', hue='familiarity', data=rec[(rec['attention level']=='both')&(rec['familiarity']>2.0)], kind='count') 
plt.ylim(0, 20)

print('')
print('')
print('Raw number of trials, HIGHEST attn level ranked 3 or 4')
print('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-856f7ddfc04c> in <module>()
# ----> 1 g = sns.factorplot(col='subject', x='attention level', hue='familiarity', data=rec[(rec['attention level']=='both')&(rec['familiarity']>2.0)], kind='count')
#       2 plt.ylim(0, 20)
#       3
#       4 print('')
#       5 print('')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     759                 other = np.asarray(other)
#     760
# --> 761             res = na_op(values, other)
#     762             if isscalar(res):
#     763                 raise TypeError('Could not compare %s type with Series' %
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     679                     result = lib.vec_compare(x, y, op)
#     680             else:
# --> 681                 result = lib.scalar_compare(x, y, op)
#     682         else:
#     683
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14194)()
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
g = sns.factorplot(col='subject', x='attention level', hue='familiarity', data=rec[(rec['attention level']=='none')&(rec['familiarity']<3.0)], kind='count') 
plt.ylim(0, 23)

print('')
print('')
print('Raw number of trials, LOWEST attn level ranked 1 or 2')
print('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7b3e2cf01bbb> in <module>()
# ----> 1 g = sns.factorplot(col='subject', x='attention level', hue='familiarity', data=rec[(rec['attention level']=='none')&(rec['familiarity']<3.0)], kind='count')
#       2 plt.ylim(0, 23)
#       3
#       4 print('')
#       5 print('')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     759                 other = np.asarray(other)
#     760
# --> 761             res = na_op(values, other)
#     762             if isscalar(res):
#     763                 raise TypeError('Could not compare %s type with Series' %
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     679                     result = lib.vec_compare(x, y, op)
#     680             else:
# --> 681                 result = lib.scalar_compare(x, y, op)
#     682         else:
#     683
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14194)()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
for x in range(5):
    data = sns.plot(ROC_data(rec[rec['subject']==x])
             
    for key in data.keys():
        plt.plot(data[key], data['novel'], '-o', label=key, markersize=8)
# Out:
#   File "<ipython-input-10-0709379e75d1>", line 4
#     for key in data.keys():
#                           ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c5d84736ba45> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
means = pd.DataFrame(pres.groupby(['subject', 'is_valid'])['RT'].mean())
means = means.reset_index()

sns.boxplot(x = "is_valid", y = "RT", data = means)
plt.savefig('../../figs/box_means.pdf')
ttest_rel(means[means['is_valid']=='valid']['RT'], means[means['is_valid']=='invalid']['RT'])
# Out:
# Ttest_relResult(statistic=-0.5258232484591914, pvalue=0.6268139281979372)

# %%
medians = pd.DataFrame(pres.groupby(['subject', 'is_valid'])['RT'].median())
medians = medians.reset_index()

sns.boxplot(x = "is_valid", y = "RT", data = medians)
plt.savefig('../../figs/box_medians.pdf')

ttest_rel(medians[medians['is_valid']=='valid']['RT'], medians[medians['is_valid']=='invalid']['RT'])
#ttest_rel(medians[medians['is_valid']=='invalid']['RT'], medians[medians['is_valid']=='valid']['RT'])
# Out:
# Ttest_relResult(statistic=-1.6469970995255365, pvalue=0.17490399672836987)

# %%
avg_rating = pd.DataFrame(rec.groupby(['subject', 'attention level'])['familiarity'].mean())
avg_rating = avg_rating.reset_index()

labels = avg_rating['attention level'].unique()

#for f in ['F','L']:
f = ' '

for idx,l in enumerate(labels):
    for each in [z for z in labels]:
        gr1 = avg_rating[(avg_rating['attention level']==l)]['familiarity'] #& (avg_rating['cat']==f)]['familiarity']
        gr2 = avg_rating[(avg_rating['attention level'] == each)]['familiarity'] #& (avg_rating['cat']==f)]['familiarity']

        t = ttest_rel(gr1,gr2)

        if t[1]<.05:
        

            print(f + ': '+l + ' vs ' + each)
            print('stat: '+str(t[0])[0:5]+'  p= '+ str(t[1])[0:5])
            print( ' ')      
            
    #sns.barplot(data=avg_rating, x = 'attention level', y = 'familiarity')
    
agg
# Out:
#  : both vs none
# stat: 2.788  p= 0.049
#
#  : both vs novel
# stat: 3.700  p= 0.020
#
#  : category vs novel
# stat: 3.353  p= 0.028
#
#  : none vs both
# stat: -2.78  p= 0.049
#
#  : none vs side
# stat: -3.96  p= 0.016
#
#  : novel vs both
# stat: -3.70  p= 0.020
#
#  : novel vs category
# stat: -3.35  p= 0.028
#
#  : side vs none
# stat: 3.961  p= 0.016
#     subject attention level cat  familiarity
# 0         0            both   F     2.850000
# 1         0            both   L     3.166667
# 2         0        category   F     2.222222
# 3         0        category   L     2.476190
# 4         0            none   F     2.000000
# 5         0            none   L     2.666667
# 6         0           novel   F     1.910256
# 7         0           novel   L     2.626667
# 8         0            side   F     2.312500
# 9         0            side   L     2.789474
# 10        1            both   F     2.900000
# 11        1            both   L     3.400000
# 12        1        category   F     2.450000
# 13        1        category   L     2.631579
# 14        1            none   F     1.315789
# 15        1            none   L     1.611111
# 16        1           novel   F     1.913043
# 17        1           novel   L     1.787500
# 18        1            side   F     1.500000
# 19        1            side   L     1.684211
# 20        2            both   F     2.100000
# 21        2            both   L     2.809524
# 22        2        category   F     2.350000
# 23        2        category   L     2.684211
# 24        2            none   F     2.350000
# 25        2            none   L     2.684211
# 26        2           novel   F     2.253165
# 27        2           novel   L     2.468354
# 28        2            side   F     2.222222
# 29        2            side   L     3.210526
# 30        3            both   F     2.421053
# 31        3            both   L     2.421053
# 32        3        category   F     2.450000
# 33        3        category   L     2.111111
# 34        3            none   F     1.789474
# 35        3            none   L     1.315789
# 36        3           novel   F     1.816901
# 37        3           novel   L     1.820513
# 38        3            side   F     1.736842
# 39        3            side   L     1.400000
# 40        4            both   F     1.947368
# 41        4            both   L     2.736842
# 42        4        category   F     1.789474
# 43        4        category   L     2.050000
# 44        4            none   F     1.700000
# 45        4            none   L     1.526316
# 46        4           novel   F     1.507463
# 47        4           novel   L     1.505495
# 48        4            side   F     1.950000
# 49        4            side   L     1.666667

# %%
#count check
#rec.groupby(['subject', 'attention level']).count()

# %%
grouped = rec.groupby(['subject', 'attention level', 'cat'])
agg = grouped.aggregate(np.mean)
agg = agg.reset_index()

# %%
#sns.boxplot(x='is_valid', y='RT', data=pres)
##plt.ylim([0,2])
#plt.savefig('../../figs/box.pdf')
#ttest_rel(pres[pres['is_valid']=='valid']['RT'],pres[pres['is_valid']=='invalid']['RT'])

# %% [markdown]
# # ANOVA

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

anova = ols('familiarity ~ C(category) + C(location)', data=rec).fit() #Specify C for Categorical
print(sm.stats.anova_lm(anova, typ=2))
# Out:
#                   sum_sq      df          F        PR(>F)
# C(category)    95.279178     2.0  54.428226  1.454271e-23
# C(location)    86.812625     2.0  49.591708  1.348398e-21
# Residual     1343.544960  1535.0        NaN           NaN

# %%
ROC_full=[]

for x in range(5):
    ROC_full.append(ROC_data(rec[rec['subject']==x]))
    
ROC_new_avg = {}
    
for kind in ROC_full[0].keys():
    kind_glom = [ROC_full[x][kind] for x in range(5)]
    ROC_new_avg[kind] = [sum(e)/len(e) for e in zip(*kind_glom)]

# %%
#ROC_new_avg

# %%
ROC_full_face=[]

for x in range(5):
    ROC_full_face.append(ROC_data(rec[(rec['subject']==x) & (rec['cat']=='F')]))
    
ROC_new_face = {}
    
for kind in ROC_full_face[0].keys():
    kind_glom_face = [ROC_full_face[x][kind] for x in range(5)]
    ROC_new_face[kind] = [sum(e)/len(e) for e in zip(*kind_glom_face)]

# %%
ROC_full_loc=[]

for x in range(5):
    ROC_full_loc.append(ROC_data(rec[(rec['subject']==x) & (rec['cat']=='L')]))
    
ROC_new_loc = {}
    
for kind in ROC_full_loc[0].keys():
    kind_glom_loc = [ROC_full_loc[x][kind] for x in range(5)]
    ROC_new_loc[kind] = [sum(e)/len(e) for e in zip(*kind_glom_loc)]

# %% [markdown]
# # Plot

# %%
sns.set_style('white')
rec2 = rec.replace('novel', np.nan)

# ROC 1 ##
data = ROC_new_avg

for key in data.keys():
    plt.plot(data[key], data['novel'], '-o', label=key, markersize=8)

plt.plot([0, 0.5, 1], [0, 0.5, 1], ':',color = 'gray', label='chance')
plt.axes().set_aspect('equal')
plt.legend(loc = (.5, .1))
plt.title('Familiarity ROC', size=24)

labels = [1, 2, 3, 4]

plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

plt.ylabel('Hit Rate', size=22)
plt.xlabel('False Alarm Rate', size=22)
plt.savefig('../../figs/ROC.pdf')
plt.show()




# ROC 2 ##

data2 = ROC_new_face
for key in data2.keys():
    plt.plot(data2[key], data['novel'], '-o', label=key, markersize=8)

plt.plot([0, 0.5, 1], [0, 0.5, 1], ':',color = 'gray', label='chance')
plt.axes().set_aspect('equal')
plt.legend(loc = (.5, .1))
plt.title('Face Familiarity', size=24)

labels = [1, 2, 3, 4]

plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

plt.ylabel('Hit Rate', size=22)
plt.xlabel('False Alarm Rate', size=22)

save_str = '../../figs/ROC_face.pdf'
plt.savefig(save_str)
plt.show()


# ROC 3 ##

data2 = ROC_new_loc
for key in data2.keys():
    plt.plot(data2[key], data['novel'], '-o', label=key, markersize=8)

plt.plot([0, 0.5, 1], [0, 0.5, 1], ':',color = 'gray', label='chance')
plt.axes().set_aspect('equal')
plt.legend(loc = (.5, .1))
plt.title('Location Familiarity', size=24)

labels = [1, 2, 3, 4]

plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

plt.ylabel('Hit Rate', size=22)
plt.xlabel('False Alarm Rate', size=22)

save_str = '../../figs/ROC_loc.pdf'
plt.savefig(save_str)
plt.show()

    
    
    
g = sns.barplot(x='attention level', y="familiarity", data=avg_rating, order=['novel','none','side','category','both'])#, kind='bar')#, kind = 'bar', hue='location', col='cat')#, col='cat')
#plt.legend(loc = (.5, .1))
plt.title('Familiarity by Attention', size=24)

plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

plt.ylabel('Familiarity', size=22)
plt.xlabel('Attention', size=22)
plt.savefig('../../figs/bar.pdf')
plt.show()



g = sns.factorplot(x='attention level', y="familiarity", data=agg, kind='bar', col='cat', order=['novel','none','side','category','both'])#, kind = 'bar', hue='location', col='cat')#, col='cat')


plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15


plt.savefig('../../figs/bar_cat.pdf')
plt.show()


g = sns.factorplot(x='attention level', y="familiarity", data=agg, kind='bar', hue='cat', order=['novel','none','side','category','both'])#, kind = 'bar', hue='location', col='cat')#, col='cat')
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
agg
# Out:
#     subject attention level cat  familiarity
# 0         0            both   F     2.850000
# 1         0            both   L     3.166667
# 2         0        category   F     2.222222
# 3         0        category   L     2.476190
# 4         0            none   F     2.000000
# 5         0            none   L     2.666667
# 6         0           novel   F     1.910256
# 7         0           novel   L     2.626667
# 8         0            side   F     2.312500
# 9         0            side   L     2.789474
# 10        1            both   F     2.900000
# 11        1            both   L     3.400000
# 12        1        category   F     2.450000
# 13        1        category   L     2.631579
# 14        1            none   F     1.315789
# 15        1            none   L     1.611111
# 16        1           novel   F     1.913043
# 17        1           novel   L     1.787500
# 18        1            side   F     1.500000
# 19        1            side   L     1.684211
# 20        2            both   F     2.100000
# 21        2            both   L     2.809524
# 22        2        category   F     2.350000
# 23        2        category   L     2.684211
# 24        2            none   F     2.350000
# 25        2            none   L     2.684211
# 26        2           novel   F     2.253165
# 27        2           novel   L     2.468354
# 28        2            side   F     2.222222
# 29        2            side   L     3.210526
# 30        3            both   F     2.421053
# 31        3            both   L     2.421053
# 32        3        category   F     2.450000
# 33        3        category   L     2.111111
# 34        3            none   F     1.789474
# 35        3            none   L     1.315789
# 36        3           novel   F     1.816901
# 37        3           novel   L     1.820513
# 38        3            side   F     1.736842
# 39        3            side   L     1.400000
# 40        4            both   F     1.947368
# 41        4            both   L     2.736842
# 42        4        category   F     1.789474
# 43        4        category   L     2.050000
# 44        4            none   F     1.700000
# 45        4            none   L     1.526316
# 46        4           novel   F     1.507463
# 47        4           novel   L     1.505495
# 48        4            side   F     1.950000
# 49        4            side   L     1.666667
