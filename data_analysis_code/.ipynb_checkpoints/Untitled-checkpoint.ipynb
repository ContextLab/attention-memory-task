# %%
import os

# %% [markdown]
# # Check data files

# %% [markdown]
# This code checks the number of participants in each experiment and verifies the number of each participant's files (and file sizes)

# %%
for exp in ['sustained_attention_experiment', 'variable_attention_experiment']:
    for grp in ['group1', 'group2']:
        
        print('##################################'); print()
        combo = '../'+exp+'/data/'+grp+'/'
        print(str(combo)); print()
        print(str(len([g for g in os.listdir(combo) if g != '.DS_Store'])) + ' participants'); print()
        print('##################################'); print()

        for x in [g for g in os.listdir(combo) if g != '.DS_Store']:

            loop = 0
            gaze_files = [a for a in os.listdir(combo+x+'/eye_data') if a != '.DS_Store']

            if len(gaze_files) <8:
                print(x); print(); print( '*** '+ str(len(gaze_files)) + ' gaze files ***'); print(); loop += 1

            file_sizes = [os.path.getsize(combo+x+'/eye_data'+'/'+k) for k in gaze_files]
            indices = [i for i, j in enumerate(file_sizes) if j < 2000000 or j > 10000000] 

            if len(indices) > 0:
                print(x); print()
                for ind in indices:
                    print(gaze_files[ind]); print(file_sizes[ind]); print(); loop += 1

            if loop >0 : 
                print('----------------- ')
# Out:
# ##################################
#
# ../sustained_attention_experiment/data/group1/
#
# 30 participants
#
# ##################################
#
# 10_2018_Oct_03
#
# 10_0.csv
# 11160420
#
# -----------------
# 31_2018_Oct_21
#
# *** 7 gaze files ***
#
# -----------------
# 09_2018_Oct_03
#
# 9_7.csv
# 73629404
#
# -----------------
# 23_2018_Oct_14
#
# 23_7
# 20467904
#
# -----------------
# 34_2018_Oct_24
#
# 34_7
# 12472819
#
# -----------------
# 08_2018_Oct_03
#
# 8_1.csv
# 62764
#
# -----------------
# 33_2018_Oct_21
#
# 33_7
# 36204424
#
# -----------------
# 26_2018_Oct_17
#
# 26_7
# 43698348
#
# -----------------
# ##################################
#
# ../sustained_attention_experiment/data/group2/
#
# 30 participants
#
# ##################################
#
# 34_2019_Oct_13
#
# 34_6.txt
# 26462
#
# -----------------
# 7_2019_Oct_13
#
# 7_5
# 0
#
# 7_4
# 12508624
#
# -----------------
# 13_2019_Oct_14
#
# 13_6
# 0
#
# 13_7
# 25001798
#
# -----------------
# 2_2019_Oct_06
#
# 2_3
# 0
#
# -----------------
# 8_2019_Oct_13
#
# 8_0.txt
# 19523466
#
# -----------------
# 32_2019_Oct_15
#
# 32_7.txt
# 11195988
#
# -----------------
# 5_2019_Oct_17
#
# 5_7.txt
# 1053231
#
# -----------------
# 1_2019_Oct_13
#
# 1_2.txt
# 10162609
#
# 1_3.txt
# 26444961
#
# 1_5.txt
# 0
#
# -----------------
# 10_2019_Oct_14
#
# 10_2
# 10949956
#
# 10_4
# 11279000
#
# 10_3
# 10800317
#
# -----------------
# 19_2019_Oct_15
#
# 19_4.txt
# 0
#
# 19_7.txt
# 145480203
#
# -----------------
# 4_2019_Oct_13
#
# 4_5.txt
# 0
#
# 4_7.txt
# 1923138
#
# -----------------
# 28_2019_Oct_09
#
# 28_6.txt
# 12077382
#
# -----------------
# 7_2019_Oct_13_b
#
# 7_7.txt
# 38922984
#
# -----------------
# 14_2019_Oct_07
#
# 14_7
# 53298212
#
# -----------------
# 3_2019_Oct_13
#
# 3_6
# 1642503
#
# 4_0
# 233093
#
# -----------------
# 18_2019_Oct_08
#
# 18_7.txt
# 19171562
#
# -----------------
# 38_2019_Oct_17
#
# 38_7
# 10854592
#
# -----------------
# 11_2019_Oct_14_b
#
# 11_4.txt
# 17850250
#
# 11_5.txt
# 11888966
#
# 11_7.txt
# 29448174
#
# 11_6.txt
# 18563604
#
# -----------------
# 5_2019_Oct_13
#
# 5_5
# 306263
#
# -----------------
# 11_2019_Oct_14
#
# 11_4
# 1909245
#
# 11_0
# 700564
#
# -----------------
# 0_2019_Oct_13
#
# 0_7
# 14939902
#
# -----------------
# ##################################
#
# ../variable_attention_experiment/data/group1/
#
# 30 participants
#
# ##################################
#
# 8_2019_Feb_28
#
# 8_7.csv
# 11170482
#
# -----------------
# 1_2019_Feb_21
#
# *** 7 gaze files ***
#
# -----------------
# 12_2019_Mar_27
#
# *** 7 gaze files ***
#
# -----------------
# 28_2019_Apr_23
#
# 28_6
# 17835695
#
# 28_7
# 17942485
#
# 28_5
# 10356512
#
# -----------------
# 33_2019_Apr_26
#
# 33_2
# 259641
#
# -----------------
# 16_2019_Apr_01
#
# 16_4.csv
# 11391858
#
# 16_5.csv
# 0
#
# -----------------
# 29_2019_Apr_23
#
# 29_5
# 16115453
#
# 29_4
# 13287772
#
# 29_6
# 22163718
#
# 29_7
# 67736160
#
# -----------------
# 5_2019_Feb_26
#
# 5_4.csv
# 596025
#
# -----------------
# 0_2019_Feb_21
#
# *** 7 gaze files ***
#
# -----------------
# 10_2019_Mar_27
#
# 10_5.csv
# 289577
#
# 10_7.csv
# 14827882
#
# 10_6.csv
# 12982857
#
# -----------------
# ##################################
#
# ../variable_attention_experiment/data/group2/
#
# 23 participants
#
# ##################################
#
# 17_2019_Nov_18
#
# 17_0
# 0
#
# -----------------
# 12_2019_Nov_17
#
# 12_4
# 0
#
# -----------------
# 25_2020_Jan_24
#
# 25_7
# 1043868
#
# -----------------
# 11_2019_Nov_17
#
# 11_2
# 55242180
#
# 11_3
# 55786735
#
# 11_1
# 54247188
#
# 11_0
# 51865300
#
# -----------------
# 18_2019_Nov_19
#
# 18_7
# 19265619
#
# -----------------
# 9_2019_Nov_16
#
# 9_4
# 17441935
#
# 9_3
# 11325418
#
# 9_5
# 21189987
#
# 9_7
# 149272219
#
# 9_6
# 20885191
#
# -----------------
# 29_2020_Jan_13
#
# 29_4
# 11358830
#
# 29_7
# 190129937
#
# -----------------
# 14_2019_Nov_17
#
# 14_0
# 13619666
#
# 14_1
# 12792160
#
# 14_4
# 15026863
#
# 14_3
# 14661493
#
# 14_2
# 18292067
#
# 14_5
# 0
#
# -----------------
# 27_2020_Jan_15
#
# 27_4
# 1263287
#
# -----------------
# 6_2019_Nov_15
#
# 6_0
# 0
#
# 6_3
# 981499
#
# -----------------
# 16_2019_Nov_18
#
# 16_7
# 41342061
#
# -----------------
# 26_2020_Jan_16
#
# 26_7
# 12183519
#
# -----------------
# 8_2019_Nov_16
#
# 8_7
# 323428578
#
# 8_0
# 15601066
#
# 8_1
# 17542892
#
# 8_6
# 33592459
#
# 8_3
# 22609773
#
# 8_4
# 26824596
#
# 8_5
# 25644155
#
# 8_2
# 17572930
#
# -----------------
# 5_2019_Nov_15
#
# 5_7
# 18246029
#
# 5_0
# 0
#
# -----------------
# 19_2019_Nov_19
#
# 19_0
# 0
#
# -----------------
# 10_2019_Nov_16
#
# 10_6
# 43595439
#
# 10_1
# 34219946
#
# 10_0
# 31465238
#
# 10_7
# 230646066
#
# 10_2
# 40814617
#
# 10_5
# 40536338
#
# 10_4
# 37557526
#
# 10_3
# 35944010
#
# -----------------
# 0_2020_Feb_07
#
# 0_7
# 99279113
#
# -----------------

# %%
print(os.listdir('../variable_attention_experiment/data/group1'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-15a0a0f3d6ed> in <module>
# ----> 1 print(os.listdir('../variable_attention_experiment/data/group1'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../variable_attention_experiment/data/group1'
