# %%
from data_checker import *

# %%
params = {'runs':8, 'presentations_per_run':10, 
          'invalid_cue_percentage':10, 'mem_to_pres':4, 
          'mem_pres_split':2}

subdir = '/Users/Student/Desktop/attention-memory-task/data/AlexPilot_2018_Aug_07'

# %%
df = sum_pd(subdir)

# %%
def check_shared(df, col1, col2,x=None):
    '''
    inputs: dataframe, two column names (strings), run#=None
    outputs: lists images shared between the columns, if any exist
    '''
    if type(x)==int:
        mask = df['Run']==x
        msg = list_compare(list(images(df.loc[mask,col1])), list(images(df.loc[mask,col2])))
        print(msg)
    else:
        msg = list_compare(list(images(df[col1])), list(images(df[col2])))
        print(msg)
    if msg != None:
        return(msg)

# %%
df[df['Trial Type']=='Presentation'].head()
# Out:
#      Unnamed: 0    Subject    Trial Type  Run  \
# 320           0  AlexPilot  Presentation    0
# 321           1  AlexPilot  Presentation    0
# 322           2  AlexPilot  Presentation    0
# 323           3  AlexPilot  Presentation    0
# 324           4  AlexPilot  Presentation    0
#
#                             Cued Composite  \
# 320  00848940307fa_sunaivdylrawbmhryfp.jpg
# 321  00719960620fa_sunadzuvtmtmgupotmf.jpg
# 322  00720960620fa_sunaecpkgfewqqreqwe.jpg
# 323  00908960530fa_sunanwjjyqqwzqrqagd.jpg
# 324  00786941205fa_sunagmhildamktmqjss.jpg
#
#                           Uncued Composite          Cued Face  \
# 320  00959960627fa_sunavxokzybtomhbmvm.jpg  00848940307fa.jpg
# 321    00909960530_sunaobtizabegtwfwul.jpg  00719960620fa.jpg
# 322  00749941201fa_sunaeuvjbmdpknaqqaj.jpg  00720960620fa.jpg
# 323  00858940307fa_sunaixpqndlwhwjtjek.jpg  00908960530fa.jpg
# 324  00957960627fa_sunavhxgmgrqsaptynb.jpg  00786941205fa.jpg
#
# ...

# %%
df2 = df[df['Trial Type']=='Presentation']
check_shared(df2, df2['Cued Composite'], df2['Uncued Composite'], x=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-b2e22c4bead6> in <module>()
#       1 df2 = df[df['Trial Type']=='Presentation']
# ----> 2 check_shared(df2, df2['Cued Composite'], df2['Uncued Composite'], x=2)
#
# <ipython-input-30-ac7ddd2b70fc> in check_shared(df, col1, col2, x)
#       6     if type(x)==int:
#       7         mask = df['Run']==x
# ----> 8         msg = list_compare(list(images(df.loc[mask,col1])), list(images(df.loc[mask,col2])))
#       9         print(msg)
#      10     else:
#
# /Users/Student/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# ...

# %%
stimulus_check(subdir, params)
# Out:
# [None]
